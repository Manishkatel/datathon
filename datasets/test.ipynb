# %%
import pandas as pd

ms_data = pd.read_csv("data_health_2023.csv")
ms_data.head()
# Out:
#    Year StateAbbr StateDesc  CountyName  CountyFIPS  LocationName DataSource  \
# 0  2023        AL   Alabama   Jefferson        1073    1073010900      BRFSS
# 1  2023        AL   Alabama   Jefferson        1073    1073011207      BRFSS
# 2  2023        AL   Alabama  Lauderdale        1077    1077010100      BRFSS
# 3  2023        AL   Alabama         Lee        1081    1081040202      BRFSS
# 4  2023        AL   Alabama         Lee        1081    1081040300      BRFSS
#
#           Category                      Measure Data_Value_Unit  ...  \
# 0       Disability  Any disability among adults               %  ...
# 1  Health Outcomes      Depression among adults               %  ...
# 2       Disability  Any disability among adults               %  ...
# 3  Health Outcomes       Arthritis among adults               %  ...
# 4  Health Outcomes         Obesity among adults               %  ...
#
#   Low_Confidence_Limit  High_Confidence_Limit  TotalPopulation  \
# ...

# %%
ms_data['Year'].value_counts()
# Out:
# Year
# 2023    2629753
# 2022     417531
# Name: count, dtype: int64

# %%
ms_data_2 = pd.read_csv("data_health_2022.csv") 
ms_data_2.head()
# Out:
#    Year StateAbbr StateDesc LocationName DataSource         Category  \
# 0  2022        AL   Alabama    Sheffield      BRFSS  Health Outcomes
# 1  2022        AL   Alabama    Courtland      BRFSS  Health Outcomes
# 2  2022        AL   Alabama  Mount Olive      BRFSS  Health Outcomes
# 3  2022        AL   Alabama    Nanafalia      BRFSS  Health Outcomes
# 4  2022        AL   Alabama  Hobson City      BRFSS  Health Outcomes
#
#                                        Measure Data_Value_Unit  \
# 0  All teeth lost among adults aged >=65 years               %
# 1  All teeth lost among adults aged >=65 years               %
# 2  All teeth lost among adults aged >=65 years               %
# 3  All teeth lost among adults aged >=65 years               %
# 4  All teeth lost among adults aged >=65 years               %
#
#            Data_Value_Type  Data_Value  ...  Low_Confidence_Limit  \
# 0  Age-adjusted prevalence        23.4  ...                  19.8
# ...

# %%
ms_data_2['Year'].value_counts()
# Out:
# Year
# 2023    1851248
# 2022     299190
# Name: count, dtype: int64
